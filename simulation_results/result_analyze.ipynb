# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from astropy import units as u
import read_reports as rr
import Differentiated_Body_Composition_Tracker as dbct


sol_to_earth = 332946.078
# Out:
# --- 0.32854127883911133 seconds ---

# %%
nd_tt, nd_n = rr.extract_data_outfile('../../data/collision_reports/chambers_1.out')
v, b = rr.extract_data_impact('../../data/collision_reports/chambers_1.out')


anna_tt, anna_n = rr.extract_data_outfile('../../data/collision_reports/Anna.out')
anna_v, anna_b = rr.extract_data_impact('../../data/collision_reports/Anna.out')

# %%
#Plots of number of bodies versus time

plt.plot(nd_n['t'], nd_n['n_bodies']/(140+14), label='New day', color='red')
#plt.plot(anna_n['t'], anna_n['n_bodies']/(260+26), label = 'Ann')

#plt.xlim(0,2e6)
plt.xlabel('time (years)')
plt.ylabel('Number of bodies in simulation')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(15,3))
plt.hist(nd_tt['coll_types'])

plt.show()

# %%
plt.figure(figsize=(15,3))
plt.hist(anna_tt['coll_types'])

plt.show()

# %%
rr.plot_b_v(anna_b, anna_v, anna_tt['coll_types'])

# %%
rr.plot_b_v(b, v, nd_tt['coll_types'])

# %%
rr.plot_v_cdf(anna_v,'red','Anna')
